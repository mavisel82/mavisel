# %% [markdown]
# # Listeler

# %% [markdown]
# Bu bölümde yapacağımız işlemler:
#
# 1. Liste oluşturma
# 2. İndeksleme ve parçalama
# 3. Temel liste metodları ve işlemleri
# 4. İç içe listeler
#
#
# ## Liste Oluşturma

# %%
Meyveler= ["erik","karpuz"]
Meyveler
# Out:
# ['erik', 'karpuz']

# %%
ArdisikSayılar = [2,4,6]
ArdisikSayılar
# Out:
# [2, 4, 6]

# %%
s = "merhaba"
ist = list(s)
ist
# Out:
# ['m', 'e', 'r', 'h', 'a', 'b', 'a']

# %%
liste4 = [2,4,6,8,]
len(liste4)
# Out:
# 4

# %%
# sonuncu eleman
liste4[-1]
# Out:
# 8

# %%
# Baştan 3. indekse kadar
liste4[:3]
# Out:
# [2, 4, 6]

# %%
# ilk eleman
liste4[-len(liste4)]
# Out:
# 2

# %%
liste4[::2]
# Out:
# [2, 6]
